# %%
### CORA
import matplotlib.pyplot as plt
import seaborn as sns

K = [1, 2, 3]
ACC_exact = [76.4, 87.5, 80.9]
ACC_che = [76.9, 85.4, 81.3]
ACC_her = [76.3, 84.7, 80.7]
ACC_lag = [76.4, 85.8, 80.5]
sns.pointplot(x=K, y=ACC_exact, zorder = 2, label='Exact')
sns.pointplot(x=K, y=ACC_che, color='orange',zorder = 2, label='GAPHeat-C')
sns.pointplot(x=K, y=ACC_her, color='green', zorder = 2, label='GAPHeat-H')
sns.pointplot(x=K, y=ACC_lag, color='red', zorder = 2, label='GAPHeat-L')
plt.xticks(fontsize=25, fontweight='bold')
plt.yticks(fontsize=20, fontweight='bold')
plt.ylabel('Accuracy (%)', fontsize=20, fontweight='bold')
plt.xlabel('K', fontsize=25, fontweight='bold')
plt.grid(True, axis='y', alpha=0.5, zorder=1)
plt.tight_layout()
plt.show()

# %%
### CORA
import matplotlib.pyplot as plt
import seaborn as sns

K = [1, 2, 3, 4]
ACC_exact = [75.8, 81.7, 80.8, 77.1]
ACC_che = [75.7, 81.9, 81.3, 77.7]
ACC_her = [75.8, 81.7, 80.9, 77.1]
ACC_lag = [75.8, 81.7, 80.8, 77.1]
sns.pointplot(x=K, y=ACC_exact, zorder = 2, label='Exact')
sns.pointplot(x=K, y=ACC_che, color='orange',zorder = 2, label='GAPHeat-C')
sns.pointplot(x=K, y=ACC_her, color='green', zorder = 2, label='GAPHeat-H')
sns.pointplot(x=K, y=ACC_lag, color='red', zorder = 2, label='GAPHeat-L')
plt.xticks(fontsize=25, fontweight='bold')
plt.yticks(fontsize=20, fontweight='bold')
plt.ylabel('Accuracy (%)', fontsize=20, fontweight='bold')
plt.xlabel('K', fontsize=25, fontweight='bold')
plt.grid(True, axis='x', alpha=0.5, zorder=1)
plt.grid(True, axis='y', alpha=0.5, zorder=1)
plt.tight_layout()
plt.show()

# %%
### CITESEER
import matplotlib.pyplot as plt
import seaborn as sns

K = [1, 2, 3]
ACC_exact = [73.2, 78.1, 68.3]
ACC_che = [72.2, 76.5, 67.4]
ACC_her = [70.1, 76.1, 64.9]
ACC_lag = [72.6, 75.9, 68.7]
sns.pointplot(x=K, y=ACC_exact, zorder = 2, label='Exact')
sns.pointplot(x=K, y=ACC_che, color='orange',zorder = 2, label='GAPHeat-C')
sns.pointplot(x=K, y=ACC_her, color='green', zorder = 2, label='GAPHeat-H')
sns.pointplot(x=K, y=ACC_lag, color='red', zorder = 2, label='GAPHeat-L')
plt.xticks(fontsize=25, fontweight='bold')
plt.yticks(fontsize=20, fontweight='bold')
plt.ylabel('Accuracy (%)', fontsize=20, fontweight='bold')
plt.xlabel('K', fontsize=25, fontweight='bold')
plt.grid(True, axis='y', alpha=0.5, zorder=1)
plt.tight_layout()
plt.show()

# %%
### CITESEER
import matplotlib.pyplot as plt
import seaborn as sns

K = [1, 2, 3, 4]
ACC_exact = [70.1,74.7,71.4,73]
ACC_che = [71.4,75.3,72.8,68.8]
ACC_her = [70.1,74,65.8,63.7]
ACC_lag = [70.1,74,70.2,72.6]
sns.pointplot(x=K, y=ACC_exact, zorder = 2, label='Exact')
sns.pointplot(x=K, y=ACC_che, color='orange',zorder = 2, label='GAPHeat-C')
sns.pointplot(x=K, y=ACC_her, color='green', zorder = 2, label='GAPHeat-H')
sns.pointplot(x=K, y=ACC_lag, color='red', zorder = 2, label='GAPHeat-L')
plt.xticks(fontsize=25, fontweight='bold')
plt.yticks(fontsize=20, fontweight='bold')
plt.ylabel('Accuracy (%)', fontsize=20, fontweight='bold')
plt.xlabel('K', fontsize=25, fontweight='bold')
plt.grid(True, axis='x', alpha=0.5, zorder=1)
plt.grid(True, axis='y', alpha=0.5, zorder=1)
plt.tight_layout()
plt.show()

# %%
### PUBMED
import matplotlib.pyplot as plt
import seaborn as sns

K = [1, 2, 3]
ACC_exact = [80, 85.3, 83.3]
ACC_che = [79.1, 84.2, 80.6]
ACC_her = [77.9, 83.6, 83.1]
ACC_lag = [77.9, 84.0, 83.4]
sns.pointplot(x=K, y=ACC_exact, zorder = 2, label='Exact')
sns.pointplot(x=K, y=ACC_che, color='orange',zorder = 2, label='GAPHeat-C')
sns.pointplot(x=K, y=ACC_her, color='green', zorder = 2, label='GAPHeat-H')
sns.pointplot(x=K, y=ACC_lag, color='red', zorder = 2, label='GAPHeat-L')
plt.xticks(fontsize=25, fontweight='bold')
plt.yticks(fontsize=20, fontweight='bold')
plt.ylabel('Accuracy (%)', fontsize=20, fontweight='bold')
plt.xlabel('K', fontsize=25, fontweight='bold')
plt.grid(True, axis='y', alpha=0.5, zorder=1)
plt.tight_layout()
plt.show()

# %%
### PUBMED
import matplotlib.pyplot as plt
import seaborn as sns

K = [1, 2, 3, 4]
ACC_exact = [76.8,80.1,79,81]
ACC_che = [78.1,80.5,79.6,76.5]
ACC_her = [76.8,80.1,78.9,75.7]
ACC_lag = [76.8,80.2,78.6,76.7]
sns.pointplot(x=K, y=ACC_exact, zorder = 2, label='Exact')
sns.pointplot(x=K, y=ACC_che, color='orange',zorder = 2, label='GAPHeat-C')
sns.pointplot(x=K, y=ACC_her, color='green', zorder = 2, label='GAPHeat-H')
sns.pointplot(x=K, y=ACC_lag, color='red', zorder = 2, label='GAPHeat-L')
plt.xticks(fontsize=25, fontweight='bold')
plt.yticks(fontsize=20, fontweight='bold')
plt.ylabel('Accuracy (%)', fontsize=20, fontweight='bold')
plt.xlabel('K', fontsize=25, fontweight='bold')
plt.grid(True, axis='x', alpha=0.5, zorder=1)
plt.grid(True, axis='y', alpha=0.5, zorder=1)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.bar([1,2,3],[0, 0, 0], linestyle='solid', label='Exact')
plt.bar([1,2,3],[0, 0, 0], linestyle='solid', label='ASAP-C')
plt.bar([1,2,3],[0, 0, 0],linestyle='solid',label='ASAP-H')
plt.bar([1,2,3],[0, 0, 0], linestyle='solid',label='ASAP-L')
plt.legend(loc=(1.5,1.5), ncol=4,fontsize=25, frameon=True, shadow=True)

plt.show()

# %%
### ADNI
import matplotlib.pyplot as plt
import seaborn as sns

K = [1, 2, 3, 4]
ACC_exact = [85.41,93.75,82.08,38.3]
ACC_che = [93.33,92.5,90.83,38.33]
ACC_her = [92.08,93.75,89.58,38.33]
ACC_lag = [93.75,94.17,75,38.3]
sns.pointplot(x=K, y=ACC_exact, zorder = 2, label='Exact')
sns.pointplot(x=K, y=ACC_che, color='orange',zorder = 2, label='GAPHeat-C')
sns.pointplot(x=K, y=ACC_her, color='green', zorder = 2, label='GAPHeat-H')
sns.pointplot(x=K, y=ACC_lag, color='red', zorder = 2, label='GAPHeat-L')
plt.xticks(fontsize=25, fontweight='bold')
plt.yticks(fontsize=20, fontweight='bold')
plt.ylabel('Accuracy (%)', fontsize=20, fontweight='bold')
plt.xlabel('K', fontsize=25, fontweight='bold')
plt.grid(True, axis='x', alpha=0.5, zorder=1)
plt.grid(True, axis='y', alpha=0.5, zorder=1)
plt.tight_layout()
plt.show()

# %%
# CORA
import numpy as np
import matplotlib.pyplot as plt
name = ['L', 'H', 'C', 'E']

colors = ['#d62728','#2ca02c','#ff7f0e','#1f77b4']
colors_black = ['#000000','#000000','#000000','#000000']
err_colors = ['#F472D0','#A4C400','#F0A30A','#1BA1E2']
all_time = [819,992,949,3165]
err = [125,250,131,442]
all_hk = [809,971,916,3156]
y = np.arange(4)

fig = plt.figure(figsize=(8,4))
ax = fig.add_subplot()
#ax.patch.set_facecolor("#dddddd")
plt.barh(y, all_time, color=colors,xerr=err, capsize=4, align='center', ecolor='black', height=0.4, zorder=2)
plt.barh([-0.1,0.9,1.9,2.9], all_hk, color= colors_black, align='edge', height=-0.1, zorder=3)
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(y, name, fontsize=20, fontweight='bold')
plt.xlabel('time (ms)', fontsize=20, fontweight='bold')
plt.grid(True, axis='x', zorder=1)
plt.tight_layout()

plt.show()

# %%
# CITESEER
import numpy as np
import matplotlib.pyplot as plt
name = ['L', 'H', 'C', 'E']

colors = ['#d62728','#2ca02c','#ff7f0e','#1f77b4']
colors_black = ['#000000','#000000','#000000','#000000']
err_colors = ['#F472D0','#A4C400','#F0A30A','#1BA1E2']
all_time = [880,899,906,4402]
err = [104,103,45,278]
all_hk = [864,876,873,4389]
y = np.arange(4)

fig = plt.figure(figsize=(8,4))
ax = fig.add_subplot()
#ax.patch.set_facecolor("#dddddd")
plt.barh(y, all_time, color=colors,xerr=err, capsize=4, align='center', ecolor='black', height=0.4, zorder=2)
plt.barh([-0.1,0.9,1.9,2.9], all_hk, color= colors_black, align='edge', height=-0.1, zorder=3)
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(y, name, fontsize=20, fontweight='bold')
plt.xlabel('time (ms)', fontsize=20, fontweight='bold')
plt.grid(True, axis='x', zorder=1)
plt.tight_layout()

plt.show()

# %%
# PUBMED
import numpy as np
import matplotlib.pyplot as plt
name = ['L', 'H', 'C', 'E']

colors = ['#d62728','#2ca02c','#ff7f0e','#1f77b4']
colors_black = ['#000000','#000000','#000000','#000000']
err_colors = ['#F472D0','#A4C400','#F0A30A','#1BA1E2']
all_time = [19253,18947,19888,171749]
err = [273,251,88,8794]
all_hk = [18535,18947,18392,169417]
y = np.arange(4)

fig = plt.figure(figsize=(8,4))
ax = fig.add_subplot()
#ax.patch.set_facecolor("#dddddd")
plt.barh(y, all_time, color=colors,xerr=err, capsize=4, align='center', ecolor='black', height=0.4, zorder=2)
plt.barh([-0.1,0.9,1.9,2.9], all_hk, color= colors_black, align='edge', height=-0.1, zorder=3)
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(y, name, fontsize=20, fontweight='bold')
plt.xlabel('time (ms)', fontsize=20, fontweight='bold')
plt.grid(True, axis='x', zorder=1)
plt.tight_layout()

plt.show()

# %%
# ADNI
import numpy as np
import matplotlib.pyplot as plt
name = ['L', 'H', 'C', 'E']

colors = ['#d62728','#2ca02c','#ff7f0e','#1f77b4']
colors_black = ['#000000','#000000','#000000','#000000']
err_colors = ['#F472D0','#A4C400','#F0A30A','#1BA1E2']
all_time = [2415,3423,3912,31688]
err = [118,175,316,846]
all_hk = [2407,3414,3903,31668]
y = np.arange(4)

fig = plt.figure(figsize=(8,4))
ax = fig.add_subplot()
#ax.patch.set_facecolor("#dddddd")
plt.barh(y, all_time, color=colors,xerr=err, capsize=4, align='center', ecolor='black', height=0.4, zorder=2)
plt.barh([-0.1,0.9,1.9,2.9], all_hk, color= colors_black, align='edge', height=-0.1, zorder=3)
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(y, name, fontsize=20, fontweight='bold')
plt.xlabel('time (ms)', fontsize=20, fontweight='bold')
plt.grid(True, axis='x', zorder=1)
plt.tight_layout()

plt.show()

# %%
# CORA
# a0=[581.4359741210938, 587.3338012695312, 778.9151000976562, 2651.987060546875]
# h0=[572.0330200195312, 573.92822265625, 758.1835327148438, 2641.679443359375]

# a1=[911.836181640625, 1459.6138916015625, 964.3028564453125, 3467.225830078125]
# h1=[902.434814453125, 1439.405029296875, 925.7257080078125, 3457.950439453125]

# a2=[709.8153076171875, 931.86865234375, 931.7590942382812, 2692.92236328125]
# h2=[702.0298461914062, 900.9500122070312, 893.2269897460938, 2684.422119140625]

# a3=[698.8175659179688, 904.248291015625, 961.7764282226562, 3209.565185546875]
# h3=[688.3287963867188, 877.9263916015625, 931.5297241210938, 3202.145263671875]

# a4=[807.7219848632812, 1011.689453125, 1267.2113037109375, 2852.567138671875]
# h4=[797.4430541992188, 993.2871704101562, 1231.44189453125, 2843.905029296875]

# a5=[866.3082885742188, 887.6922607421875, 927.7993774414062, 3857.52880859375]
# h5=[855.8008422851562, 860.0985717773438, 896.4610595703125, 3850.3095703125]

# a6=[899.82666015625, 843.4800415039062, 1045.529541015625, 2879.196044921875]
# h6=[889.375732421875, 822.302734375, 1002.9117431640625, 2870.7021484375]

# a7=[801.8421630859375, 885.8206787109375, 772.1287841796875, 3983.40087890625]
# h7=[791.1741333007812, 867.0494995117188, 746.4693603515625, 3975.1259765625]

# a8=[862.6083984375, 984.2278442382812, 905.4832763671875, 3094.4736328125]
# h8=[853.128173828125, 973.6304931640625, 866.334716796875, 3086.023681640625]

# a9=[1055.1593017578125, 1428.4666748046875, 941.0908203125, 2963.13232421875]
# h9=[1044.6080322265625, 1409.3526611328125, 915.2501831054688, 2955.717529296875]

###################################################################################

# CITESEER
# a0=[964.60595703125, 883.2245483398438, 932.974609375, 4490.390625]
# h0=[959.2493896484375, 855.2274169921875, 896.8652954101562, 4477.47802734375]

# a1=[1004.0197143554688, 995.4908447265625, 955.978759765625, 4850.13623046875]
# h1=[986.5113525390625, 965.6688842773438, 900.7933349609375, 4838.98046875]

# a2=[821.7894897460938, 789.8101806640625, 911.7071533203125, 4325.38134765625]
# h2=[803.4744262695312, 771.9761962890625, 882.4094848632812, 4315.07958984375]

# a3=[784.2713623046875, 686.2666015625, 891.6787109375, 4057.184326171875]
# h3=[766.961669921875, 662.60888671875, 862.424072265625, 4046.783447265625]

# a4=[843.484130859375, 908.157958984375, 891.244384765625, 4953.1044921875]
# h4=[826.1509399414062, 883.6505737304688, 862.0472412109375, 4942.71875]

# a5=[912.68505859375, 1022.9698486328125, 903.4873046875, 4209.2607421875]
# h5=[899.620849609375, 1006.38720703125, 874.197998046875, 4191.98876953125]

# a6=[904.1959838867188, 910.5735473632812, 968.6998901367188, 4338.75341796875]
# h6=[886.8047485351562, 884.8291625976562, 939.4421997070312, 4323.734375]

# a7=[772.1021728515625, 1024.93896484375, 845.8782958984375, 4119.11767578125]
# h7=[755.178466796875, 1000.5247802734375, 816.66455078125, 4101.1396484375]

# a8=[1070.271484375, 951.9277954101562, 944.3082275390625, 4274.85986328125]
# h8=[1053.0098876953125, 927.2576293945312, 915.1365356445312, 4264.48095703125]

# a9=[727.7117309570312, 826.25537109375, 817.5360107421875, 4401.95458984375]
# h9=[710.46142578125, 803.0996704101562, 788.41650390625, 4391.70458984375]

###################################################################################

# PUBMED
a0=[19176.224609375, 18580.640625, 20070.798828125, 174251.453125]
h0=[18448.9140625, 17864.591796875, 18566.564453125, 171916.328125]

a1=[19158.998046875, 18947.38671875, 19909.255859375, 190119.328125]
h1=[18439.08203125, 18234.501953125, 18404.298828125, 187776.921875]

a2=[19285.849609375, 18832.1640625, 19877.9375, 173994.0]
h2=[18563.12890625, 18115.900390625, 18371.36328125, 171653.34375]

a3=[19142.857421875, 18714.33984375, 19949.62890625, 155490.125]
h3=[18412.72265625, 17997.830078125, 18442.982421875, 153140.359375]

a4=[19855.724609375, 19126.453125, 19749.6796875, 163163.75]
h4=[19147.76171875, 18421.66796875, 18259.650390625, 160842.015625]

a5=[18958.505859375, 19041.8515625, 19816.181640625, 167223.125]
h5=[18244.228515625, 18343.2265625, 18326.283203125, 164897.890625]

a6=[19686.9375, 19036.478515625, 19797.88671875, 172157.15625]
h6=[18972.537109375, 18336.943359375, 18306.662109375, 169825.703125]

a7=[19104.392578125, 19220.134765625, 19904.068359375, 172854.3125]
h7=[18388.767578125, 18519.802734375, 18414.67578125, 170531.5625]

a8=[19069.083984375, 19377.05078125, 19966.181640625, 179296.09375]
h8=[18353.30859375, 18675.748046875, 18476.158203125, 176970.28125]

a9=[19100.34765625, 18600.1484375, 19841.435546875, 168946.890625]
h9=[18383.37890625, 17900.916015625, 18352.896484375, 166617.515625]

###################################################################################

# ADNI
# a0=[2584.2880859375, 3619.357666015625, 4022.41015625, 32442.158203125]
# h0=[2573.074462890625, 3609.820068359375, 4012.54296875, 32418.578125]

# a1=[2357.02587890625, 3283.97509765625, 3708.874755859375, 30804.04296875]
# h1=[2348.919921875, 3275.533447265625, 3700.556884765625, 30783.015625]

# a2=[2529.5595703125, 3758.05224609375, 4789.00341796875, 33116.796875]
# h2=[2521.777099609375, 3738.56982421875, 4772.94775390625, 33103.15234375]

# a3=[2419.31884765625, 3365.815185546875, 3913.03076171875, 32380.83984375]
# h3=[2411.366455078125, 3357.968505859375, 3902.2939453125, 32348.095703125]

# a4=[2355.119140625, 3308.3974609375, 3763.38134765625, 31935.376953125]
# h4=[2346.99169921875, 3300.421630859375, 3755.450439453125, 31921.93359375]

# a5=[2642.926513671875, 3666.403564453125, 4031.594482421875, 31895.5546875]
# h5=[2634.9384765625, 3657.120849609375, 4022.950927734375, 31881.458984375]

# a6=[2287.204345703125, 3271.48974609375, 3711.345703125, 30694.826171875]
# h6=[2279.49462890625, 3263.3896484375, 3703.396240234375, 30670.58984375]

# a7=[2331.390869140625, 3307.865234375, 3707.220947265625, 32096.5625]
# h7=[2323.525634765625, 3299.840087890625, 3699.2626953125, 32078.16015625]

# a8=[2313.084228515625, 3267.86962890625, 3716.032470703125, 31156.080078125]
# h8=[2304.785400390625, 3259.490234375, 3706.252197265625, 31137.650390625]

# a9=[2335.055908203125, 3388.74072265625, 3764.884521484375, 30363.650390625]
# h9=[2327.251953125, 3379.292236328125, 3756.1435546875, 30342.646484375]

###################################################################################

# %%
A_exa=[]
H_exa=[]

A_che=[]
H_che=[]

A_her=[]
H_her=[]

A_lag=[]
H_lag=[]

A_exa.append(a0[3])
A_exa.append(a1[3])
A_exa.append(a2[3])
A_exa.append(a3[3])
A_exa.append(a4[3])
A_exa.append(a5[3])
A_exa.append(a6[3])
A_exa.append(a7[3])
A_exa.append(a8[3])
A_exa.append(a9[3])
print(np.mean(A_exa), np.std(A_exa))

H_exa.append(h0[3])
H_exa.append(h1[3])
H_exa.append(h2[3])
H_exa.append(h3[3])
H_exa.append(h4[3])
H_exa.append(h5[3])
H_exa.append(h6[3])
H_exa.append(h7[3])
H_exa.append(h8[3])
H_exa.append(h9[3])
print(np.mean(H_exa), np.std(H_exa))

A_che.append(a0[2])
A_che.append(a1[2])
A_che.append(a2[2])
A_che.append(a3[2])
A_che.append(a4[2])
A_che.append(a5[2])
A_che.append(a6[2])
A_che.append(a7[2])
A_che.append(a8[2])
A_che.append(a9[2])
print(np.mean(A_che), np.std(A_che))

H_che.append(h0[2])
H_che.append(h1[2])
H_che.append(h2[2])
H_che.append(h3[2])
H_che.append(h4[2])
H_che.append(h5[2])
H_che.append(h6[2])
H_che.append(h7[2])
H_che.append(h8[2])
H_che.append(h9[2])
print(np.mean(H_che), np.std(H_che))

A_her.append(a0[1])
A_her.append(a1[1])
A_her.append(a2[1])
A_her.append(a3[1])
A_her.append(a4[1])
A_her.append(a5[1])
A_her.append(a6[1])
A_her.append(a7[1])
A_her.append(a8[1])
A_her.append(a9[1])
print(np.mean(A_her), np.std(A_her))

H_her.append(h0[1])
H_her.append(h1[1])
H_her.append(h2[1])
H_her.append(h3[1])
H_her.append(h4[1])
H_her.append(h5[1])
H_her.append(h6[1])
H_her.append(h7[1])
H_her.append(h8[1])
H_her.append(h9[1])
print(np.mean(H_her), np.std(H_her))

A_lag.append(a0[0])
A_lag.append(a1[0])
A_lag.append(a2[0])
A_lag.append(a3[0])
A_lag.append(a4[0])
A_lag.append(a5[0])
A_lag.append(a6[0])
A_lag.append(a7[0])
A_lag.append(a8[0])
A_lag.append(a9[0])
print(np.mean(A_lag), np.std(A_lag))

H_lag.append(h0[0])
H_lag.append(h1[0])
H_lag.append(h2[0])
H_lag.append(h3[0])
H_lag.append(h4[0])
H_lag.append(h5[0])
H_lag.append(h6[0])
H_lag.append(h7[0])
H_lag.append(h8[0])
H_lag.append(h9[0])
print(np.mean(H_lag), np.std(H_lag))
# Out:
# 171749.6234375 8794.947838320688
# 169417.1921875 8794.969017339927
# 19888.30546875 88.72162332351631
# 18392.153515625 84.78938996768716
# 18947.66484375 251.11588772363692
# 18241.112890625 255.18562152411272
# 19253.8921875 273.02946074933516
# 18535.3830078125 275.8986968308685
